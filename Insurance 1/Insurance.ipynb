# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
train=pd.read_csv('train.csv')
test=pd.read_csv("test.csv")
pd.set_option('display.max_columns',len(train.columns))

# %%
train.head(10)
# Out:
#    id   Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0   0  19.0  Female        10049.0        Married                   1.0
# 1   1  39.0  Female        31678.0       Divorced                   3.0
# 2   2  23.0    Male        25602.0       Divorced                   3.0
# 3   3  21.0    Male       141855.0        Married                   2.0
# 4   4  21.0    Male        39651.0         Single                   1.0
# 5   5  29.0    Male        45963.0        Married                   1.0
# 6   6  41.0    Male        40336.0        Married                   0.0
# 7   7  48.0  Female       127237.0       Divorced                   2.0
# 8   8  21.0    Male         1733.0       Divorced                   3.0
# 9   9  44.0    Male        52447.0        Married                   2.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1        Master's            NaN     15.569731     Rural  Comprehensive
# 2     High School  Self-Employed     47.177549  Suburban        Premium
# 3      Bachelor's            NaN     10.938144     Rural          Basic
# 4      Bachelor's  Self-Employed     20.376094     Rural        Premium
# 5      Bachelor's            NaN     33.053198     Urban        Premium
# 6             PhD            NaN           NaN     Rural          Basic
# 7     High School       Employed      5.769783  Suburban  Comprehensive
# 8      Bachelor's            NaN     17.869551     Urban        Premium
# 9        Master's       Employed     20.473718     Urban  Comprehensive
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0           NaN                 3.0
# 3              1.0          0.0         367.0                 1.0
# 4              0.0          8.0         598.0                 4.0
# 5              2.0          4.0         614.0                 5.0
# 6              2.0          8.0         807.0                 6.0
# 7              1.0         11.0         398.0                 5.0
# 8              1.0         10.0         685.0                 8.0
# 9              1.0          9.0         635.0                 3.0
#
#             Policy Start Date Customer Feedback Smoking Status  \
# 0  2023-12-23 15:21:39.134960              Poor             No
# 1  2023-06-12 15:21:39.111551           Average            Yes
# 2  2023-09-30 15:21:39.221386              Good            Yes
# 3  2024-06-12 15:21:39.226954              Poor            Yes
# 4  2021-12-01 15:21:39.252145              Poor            Yes
# 5  2022-05-20 15:21:39.207847           Average             No
# 6  2020-02-21 15:21:39.219432              Poor             No
# 7  2022-08-08 15:21:39.181605           Average             No
# 8  2020-12-14 15:21:39.198406           Average             No
# 9  2020-08-02 15:21:39.144722              Poor             No
#
#   Exercise Frequency Property Type  Premium Amount
# 0             Weekly         House          2869.0
# 1            Monthly         House          1483.0
# 2             Weekly         House           567.0
# 3              Daily     Apartment           765.0
# 4             Weekly         House          2022.0
# 5             Weekly         House          3202.0
# 6             Weekly         House           439.0
# 7             Rarely         Condo           111.0
# 8            Monthly         Condo           213.0
# 9              Daily         Condo            64.0

# %%
train=train.drop_duplicates()
def split(Data,Target,id):
  y=Data[Target].copy()
  x=Data.drop([Target,id],axis=1).copy()
  return x,y
x,y=split(train,'Premium Amount','id')

# %%
x.head(10)
# Out:
#     Age  Gender  Annual Income Marital Status  Number of Dependents  \
# 0  19.0  Female        10049.0        Married                   1.0
# 1  39.0  Female        31678.0       Divorced                   3.0
# 2  23.0    Male        25602.0       Divorced                   3.0
# 3  21.0    Male       141855.0        Married                   2.0
# 4  21.0    Male        39651.0         Single                   1.0
# 5  29.0    Male        45963.0        Married                   1.0
# 6  41.0    Male        40336.0        Married                   0.0
# 7  48.0  Female       127237.0       Divorced                   2.0
# 8  21.0    Male         1733.0       Divorced                   3.0
# 9  44.0    Male        52447.0        Married                   2.0
#
#   Education Level     Occupation  Health Score  Location    Policy Type  \
# 0      Bachelor's  Self-Employed     22.598761     Urban        Premium
# 1        Master's            NaN     15.569731     Rural  Comprehensive
# 2     High School  Self-Employed     47.177549  Suburban        Premium
# 3      Bachelor's            NaN     10.938144     Rural          Basic
# 4      Bachelor's  Self-Employed     20.376094     Rural        Premium
# 5      Bachelor's            NaN     33.053198     Urban        Premium
# 6             PhD            NaN           NaN     Rural          Basic
# 7     High School       Employed      5.769783  Suburban  Comprehensive
# 8      Bachelor's            NaN     17.869551     Urban        Premium
# 9        Master's       Employed     20.473718     Urban  Comprehensive
#
#    Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0              2.0         17.0         372.0                 5.0
# 1              1.0         12.0         694.0                 2.0
# 2              1.0         14.0           NaN                 3.0
# 3              1.0          0.0         367.0                 1.0
# 4              0.0          8.0         598.0                 4.0
# 5              2.0          4.0         614.0                 5.0
# 6              2.0          8.0         807.0                 6.0
# 7              1.0         11.0         398.0                 5.0
# 8              1.0         10.0         685.0                 8.0
# 9              1.0          9.0         635.0                 3.0
#
#             Policy Start Date Customer Feedback Smoking Status  \
# 0  2023-12-23 15:21:39.134960              Poor             No
# 1  2023-06-12 15:21:39.111551           Average            Yes
# 2  2023-09-30 15:21:39.221386              Good            Yes
# 3  2024-06-12 15:21:39.226954              Poor            Yes
# 4  2021-12-01 15:21:39.252145              Poor            Yes
# 5  2022-05-20 15:21:39.207847           Average             No
# 6  2020-02-21 15:21:39.219432              Poor             No
# 7  2022-08-08 15:21:39.181605           Average             No
# 8  2020-12-14 15:21:39.198406           Average             No
# 9  2020-08-02 15:21:39.144722              Poor             No
#
#   Exercise Frequency Property Type
# 0             Weekly         House
# 1            Monthly         House
# 2             Weekly         House
# 3              Daily     Apartment
# 4             Weekly         House
# 5             Weekly         House
# 6             Weekly         House
# 7             Rarely         Condo
# 8            Monthly         Condo
# 9              Daily         Condo

# %%
# @title info

def describe(df):
  desc=pd.DataFrame()
  desc['dtype']=df.dtypes
  desc['null']=df.isnull().sum()
  desc['%null'] = desc['null'] / len(df) * 100
  # desc['mean']=df.mean()
  # desc['median']=df.median()
  #desc['%unique'] = desc['nunique'] /len(df)*100
  desc = pd.concat([desc,df.describe(include = 'all').T],axis=1).sort_values(by='null',ascending=False)
  desc['count']=df.count()
  desc['unique']=df.nunique()
  # desc['freq/mean']=desc['freq'].fillna(desc['mean']).drop(['freq','mean'],axis=1)
  display(desc)
describe(train)
# Out:
#                         dtype    null      %null    count   unique  \
# Previous Claims       float64  364029  30.335750   835971       10
# Occupation             object  358075  29.839583   841925        3
# Credit Score          float64  137882  11.490167  1062118      550
# Number of Dependents  float64  109672   9.139333  1090328        5
# Customer Feedback      object   77824   6.485333  1122176        3
# Health Score          float64   74076   6.173000  1125924   532655
# Annual Income         float64   44949   3.745750  1155051    88593
# Age                   float64   18705   1.558750  1181295       47
# Marital Status         object   18529   1.544083  1181471        3
# Vehicle Age           float64       6   0.000500  1199994       20
# Insurance Duration    float64       1   0.000083  1199999        9
# id                      int64       0   0.000000  1200000  1200000
# Property Type          object       0   0.000000  1200000        3
# Exercise Frequency     object       0   0.000000  1200000        4
# Smoking Status         object       0   0.000000  1200000        2
# Policy Type            object       0   0.000000  1200000        3
# Policy Start Date      object       0   0.000000  1200000   167381
# Location               object       0   0.000000  1200000        3
# Education Level        object       0   0.000000  1200000        4
# Gender                 object       0   0.000000  1200000        2
# Premium Amount        float64       0   0.000000  1200000     4794
#
#                                              top    freq          mean  \
# Previous Claims                              NaN     NaN      1.002689
# Occupation                              Employed  282750           NaN
# Credit Score                                 NaN     NaN     592.92435
# Number of Dependents                         NaN     NaN      2.009934
# Customer Feedback                        Average  377905           NaN
# Health Score                                 NaN     NaN     25.613908
# Annual Income                                NaN     NaN  32745.217777
# Age                                          NaN     NaN     41.145563
# Marital Status                            Single  395391           NaN
# Vehicle Age                                  NaN     NaN      9.569889
# Insurance Duration                           NaN     NaN      5.018219
# id                                           NaN     NaN      599999.5
# Property Type                              House  400349           NaN
# Exercise Frequency                        Weekly  306179           NaN
# Smoking Status                               Yes  601873           NaN
# Policy Type                              Premium  401846           NaN
# Policy Start Date     2020-02-08 15:21:39.134960     142           NaN
# Location                                Suburban  401542           NaN
# Education Level                         Master's  303818           NaN
# Gender                                      Male  602571           NaN
# Premium Amount                               NaN     NaN   1102.544822
#
#                                 std       min        25%        50%  \
# Previous Claims             0.98284       0.0        0.0        1.0
# Occupation                      NaN       NaN        NaN        NaN
# Credit Score             149.981945     300.0      468.0      595.0
# Number of Dependents       1.417338       0.0        1.0        2.0
# Customer Feedback               NaN       NaN        NaN        NaN
# Health Score              12.203462  2.012237  15.918959  24.578648
# Annual Income          32179.506124       1.0     8001.0    23911.0
# Age                        13.53995      18.0       30.0       41.0
# Marital Status                  NaN       NaN        NaN        NaN
# Vehicle Age                5.776189       0.0        5.0       10.0
# Insurance Duration         2.594331       1.0        3.0        5.0
# id                    346410.305852       0.0  299999.75   599999.5
# Property Type                   NaN       NaN        NaN        NaN
# Exercise Frequency              NaN       NaN        NaN        NaN
# Smoking Status                  NaN       NaN        NaN        NaN
# Policy Type                     NaN       NaN        NaN        NaN
# Policy Start Date               NaN       NaN        NaN        NaN
# Location                        NaN       NaN        NaN        NaN
# Education Level                 NaN       NaN        NaN        NaN
# Gender                          NaN       NaN        NaN        NaN
# Premium Amount           864.998859      20.0      514.0      872.0
#
#                             75%        max
# Previous Claims             2.0        9.0
# Occupation                  NaN        NaN
# Credit Score              721.0      849.0
# Number of Dependents        3.0        4.0
# Customer Feedback           NaN        NaN
# Health Score          34.527209  58.975914
# Annual Income           44634.0   149997.0
# Age                        53.0       64.0
# Marital Status              NaN        NaN
# Vehicle Age                15.0       19.0
# Insurance Duration          7.0        9.0
# id                    899999.25  1199999.0
# Property Type               NaN        NaN
# Exercise Frequency          NaN        NaN
# Smoking Status              NaN        NaN
# Policy Type                 NaN        NaN
# Policy Start Date           NaN        NaN
# Location                    NaN        NaN
# Education Level             NaN        NaN
# Gender                      NaN        NaN
# Premium Amount           1509.0     4999.0

# %%
null_counts= train.isnull().sum()

# Filter columns where null values are below the threshold
selected_columns=[ i for i in null_counts.index if i != "Policy Start Date" ]

# %%
selected_columns
# Out:
# ['id',
#  'Age',
#  'Gender',
#  'Annual Income',
#  'Marital Status',
#  'Number of Dependents',
#  'Education Level',
#  'Occupation',
#  'Health Score',
#  'Location',
#  'Policy Type',
#  'Previous Claims',
#  'Vehicle Age',
#  'Credit Score',
#  'Insurance Duration',
#  'Customer Feedback',
#  'Smoking Status',
#  'Exercise Frequency',
#  'Property Type',
#  'Premium Amount']

# %%
def cat_fea(train):

  unique_counts = train[selected_columns].nunique()
  #Threshold to distinguish continous and categorical
  threshold = 10

  continuous_vars = unique_counts[unique_counts > threshold].index.tolist()
  categorical_vars = unique_counts[unique_counts <= threshold].index.tolist()
  return continuous_vars,categorical_vars


cont,cat=cat_fea(train)

# %%
# @title category feature disturbutions
import warnings
warnings.filterwarnings("ignore")
def target_plot(column,train):
    custom_palette = sns.color_palette("pastel")
    f, ax = plt.subplots(1, 2, figsize=(14,6))
    train[column].value_counts().plot.pie(autopct='%2.1f%%', ax=ax[0], shadow=True, colors=custom_palette)
    ax[0].set_ylabel(f'{column}')
    sns.countplot(x=column, data=train, ax=ax[1], palette=custom_palette,hue=column)
    ax[0].set_title(f'{column} Distribution (Pie Chart)', fontsize=14)
    ax[1].set_title(f'{column} Count (Bar Plot)', fontsize=14)
    plt.suptitle(f'{column} Visualization', fontsize=16, fontweight='bold')
    plt.grid(axis='y', linestyle='--', alpha=0.5)
    plt.show()
    print("Columns in Target column are:",train[column].value_counts())
for i in cat:
 target_plot(i,train)
# Out:
# Columns in Target column are: Gender
# Male      602571
# Female    597429
# Name: count, dtype: int64
# Columns in Target column are: Marital Status
# Single      395391
# Married     394316
# Divorced    391764
# Name: count, dtype: int64
# Columns in Target column are: Number of Dependents
# 3.0    221475
# 4.0    220340
# 0.0    218124
# 2.0    215313
# 1.0    215076
# Name: count, dtype: int64
# Columns in Target column are: Education Level
# Master's       303818
# PhD            303507
# Bachelor's     303234
# High School    289441
# Name: count, dtype: int64
# Columns in Target column are: Occupation
# Employed         282750
# Self-Employed    282645
# Unemployed       276530
# Name: count, dtype: int64
# Columns in Target column are: Location
# Suburban    401542
# Rural       400947
# Urban       397511
# Name: count, dtype: int64
# Columns in Target column are: Policy Type
# Premium          401846
# Comprehensive    399600
# Basic            398554
# Name: count, dtype: int64
# Columns in Target column are: Previous Claims
# 0.0    305433
# 1.0    300811
# 2.0    167661
# 3.0     49011
# 4.0     10668
# 5.0      2018
# 6.0       302
# 7.0        58
# 8.0         8
# 9.0         1
# Name: count, dtype: int64
# Columns in Target column are: Insurance Duration
# 9.0    137781
# 1.0    135072
# 8.0    133800
# 7.0    133592
# 5.0    132253
# 4.0    132182
# 6.0    132141
# 3.0    132018
# 2.0    131160
# Name: count, dtype: int64
# Columns in Target column are: Customer Feedback
# Average    377905
# Poor       375518
# Good       368753
# Name: count, dtype: int64
# Columns in Target column are: Smoking Status
# Yes    601873
# No     598127
# Name: count, dtype: int64
# Columns in Target column are: Exercise Frequency
# Weekly     306179
# Monthly    299830
# Rarely     299420
# Daily      294571
# Name: count, dtype: int64
# Columns in Target column are: Property Type
# House        400349
# Apartment    399978
# Condo        399673
# Name: count, dtype: int64

# %%
# @title continous feature disturbutions
def target3_plot(column,train):
      import warnings
      warnings.filterwarnings("ignore")
      hue_columns = ['Pastry', 'Z_Scratch', 'K_Scatch', 'Stains', 'Dirtiness', 'Bumps', 'Other_Faults']
      fig, axes = plt.subplots(1, 2, figsize=(14, 4))  # Create subplots with 1 row and 2 columns

      # Plot histogram with hue
      sns.histplot(data=train, x=column, hue_order=hue_columns, bins=50, kde=True, ax=axes[0])
      axes[0].set_title(f'Histogram of {column} with Hue')
      axes[0].set_xlabel(column)
      axes[0].set_ylabel('Count')
      # axes[0].legend(title='Fault Types', loc='upper right',fontsize="x-large")

      # Plot KDE plot with hue
      sns.kdeplot(data=train, x=column, shade=True,hue_order=hue_columns, ax=axes[1])
      axes[1].set_title(f'KDE Plot of {column} with Hue')
      axes[1].set_xlabel(column)
      axes[1].set_ylabel('Density')
      # axes[1].legend(title='Fault Types', loc='upper right',fontsize="x-large")

      plt.tight_layout()  # Adjust spacing between subplots
      plt.show()

for i in cont:
   target3_plot(i,train)

# %%
from sklearn import preprocessing

def encoder(data):
  for col in data.columns:
      if data.dtypes[col] == "object":
          le = preprocessing.LabelEncoder()
          le.fit(data[col])
          data[col] = le.transform(data[col])
  return data
x=encoder(x)

# %%
x
# Out:
#           Age  Gender  Annual Income  Marital Status  Number of Dependents  \
# 0        19.0       0        10049.0               1                   1.0
# 1        39.0       0        31678.0               0                   3.0
# 2        23.0       1        25602.0               0                   3.0
# 3        21.0       1       141855.0               1                   2.0
# 4        21.0       1        39651.0               2                   1.0
# ...       ...     ...            ...             ...                   ...
# 1199995  36.0       0        27316.0               1                   0.0
# 1199996  54.0       1        35786.0               0                   NaN
# 1199997  19.0       1        51884.0               0                   0.0
# 1199998  55.0       1            NaN               2                   1.0
# 1199999  21.0       0            NaN               0                   0.0
#
#          Education Level  Occupation  Health Score  Location  Policy Type  \
# 0                      0           1     22.598761         2            2
# 1                      2           3     15.569731         0            1
# 2                      1           1     47.177549         1            2
# 3                      0           3     10.938144         0            0
# 4                      0           1     20.376094         0            2
# ...                  ...         ...           ...       ...          ...
# 1199995                2           2     13.772907         2            2
# 1199996                2           1     11.483482         0            1
# 1199997                2           3     14.724469         1            0
# 1199998                3           3     18.547381         1            2
# 1199999                3           3     10.125323         0            2
#
#          Previous Claims  Vehicle Age  Credit Score  Insurance Duration  \
# 0                    2.0         17.0         372.0                 5.0
# 1                    1.0         12.0         694.0                 2.0
# 2                    1.0         14.0           NaN                 3.0
# 3                    1.0          0.0         367.0                 1.0
# 4                    0.0          8.0         598.0                 4.0
# ...                  ...          ...           ...                 ...
# 1199995              NaN          5.0         372.0                 3.0
# 1199996              NaN         10.0         597.0                 4.0
# 1199997              0.0         19.0           NaN                 6.0
# 1199998              1.0          7.0         407.0                 4.0
# 1199999              0.0         18.0         502.0                 6.0
#
#          Policy Start Date  Customer Feedback  Smoking Status  \
# 0                   145522                  2               0
# 1                   127832                  0               1
# 2                   137880                  1               1
# 3                   161517                  2               1
# 4                    76621                  2               1
# ...                    ...                ...             ...
# 1199995             124181                  2               0
# 1199996             102449                  2               0
# 1199997              59151                  1               0
# 1199998              69979                  2               0
# 1199999              34343                  1               1
#
#          Exercise Frequency  Property Type
# 0                         3              2
# 1                         1              2
# 2                         3              2
# 3                         0              0
# 4                         3              2
# ...                     ...            ...
# 1199995                   0              0
# 1199996                   3              0
# 1199997                   1              1
# 1199998                   0              0
# 1199999                   1              2
#
# [1200000 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split

xtr,xte,ytr,yte=train_test_split(x,y,test_size=0.2,shuffle=True )

# @title gaussian
from sklearn.ensemble import HistGradientBoostingRegressor
model=HistGradientBoostingRegressor()

model.fit(xtr,ytr)
model.score(xte,yte)
# Out:
# 0.06778335197200502

# %%
l=model.predict(encoder(test.drop('id',axis=1)))
df=pd.DataFrame()
df['Premium Amount']=l
df['id']=test['id']
df.to_csv("sample_submission.csv", index=False)

# %%
from xgboost import XGBClassifier
