# %%
#linear aggresssion

-

# %% [markdown]
# # linear aggression
#   - train data and test data
#   - cost function
#   - gradient descent
#   - repeat...

# %%
import numpy as np
import matplotlib.pyplot as plt
