# %%
text='''Kalinowski was born in Mostowlany, in Grodnensky Uyezd of the Russian Empire (now Mostowlany, Poland) to a szlachta family. The Kalinowski family hailed from the Polish region of Mazovia and bore the Kalinowa coat of arms. His father, Szymon, was a manager of the Mostowlany farm and manor. His older brother, Wiktor Kalinowski [be] would become a historian. In 1849 his father, Szymon bought a folwark near Svislach (now Belarus) where Konstanty grew up.[3]

After graduating from a local school in Svislach in 1855, Kalinowski entered the faculty of Medicine of the University of Moscow as an external student.[3] After one semester he moved to St. Petersburg, where his brother was and joined the faculty of Law at the University of St. Petersburg. Along with his brother Victor, he got himself involved in Polish students' conspiracies and secret cultural societies, headed by Zygmunt Sierakowski and Jarosław Dąbrowski. After graduating in 1860, Konstanty traveled to Vilnius where he unsuccessfully applied to join the civil service under Vladimir Ivanovich Nazimov [ru].[3]
Career
Literary work

Konstanty then returned to the Grodno area in 1861. Konstanty started publishing Mużyckaja prauda (Peasants' Truth), the first newspaper in Belarusian, written in Łacinka, first published in June 1862.[4] The Peasants' Truth was issued seven times until 1863.[3] Konstanty also published two other Polish language newspapers.[5] Konstanty was more aligned with the Reds which represented a democratic movement uniting peasants, workers, and some clergy rather than the more moderate Whites.[3]

In his literary work, Kalinowski underlined the need to liberate all people of the former Polish–Lithuanian Commonwealth from Russia's occupation and to conserve and promote the Greek Catholic faith and Belarusian language. He also promoted the idea of activisation of peasants for the cause of national liberation, the idea that was until then dominated by the gentry. He favored the Polish–Lithuanian Commonwealth's traditions of democracy, tolerance and freedom, as opposed to national oppression of cultures dominated by Imperial Russia:

    While the Polish Council gives all fraternal peoples self-help, the Muscovite not only does not do so, but even where Poles, Lithuanians and Belarusians lived, he opens Muscovite schools, and in these schools they teach in Muscovite language, where you will never hear a word in Polish, in Lithuanian or in Belarusian, as the people want [...][6][7]

There is some academic debate about which texts to attribute to Konstanty.[2] Konstanty was unhappy with the timing and objectives of the January Uprising, which broke out on 23 January 1863. There had been a growing rift between him and other leaders of the uprising in Warsaw.[3]

After the outbreak of the January Uprising, he was involved in the secret Provincial Lithuanian Committee [pl; be-tarask] in Vilnius. Soon he was promoted to the commissar of the Polish National Government for the Grodno Governorate. His writings made him popular both among the peasants and the gentry, which enabled the partisan units under his command to grow rapidly. Because of his successes he was promoted to the rank of Plenipotentiary Commissar of the Government for Lithuania (Polish: Komisarz Pełnomocny Rządu na Litwę), which made him the commander-in-chief of all partisan units fighting in the areas of the former Grand Duchy of Lithuania, which are in modern Lithuania, Belarus, eastern Poland and Ukraine. '''

# %%
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
txt=text.strip()
print(txt)
# Out:
# Kalinowski was born in Mostowlany, in Grodnensky Uyezd of the Russian Empire (now Mostowlany, Poland) to a szlachta family. The Kalinowski family hailed from the Polish region of Mazovia and bore the Kalinowa coat of arms. His father, Szymon, was a manager of the Mostowlany farm and manor. His older brother, Wiktor Kalinowski [be] would become a historian. In 1849 his father, Szymon bought a folwark near Svislach (now Belarus) where Konstanty grew up.[3]
#
# After graduating from a local school in Svislach in 1855, Kalinowski entered the faculty of Medicine of the University of Moscow as an external student.[3] After one semester he moved to St. Petersburg, where his brother was and joined the faculty of Law at the University of St. Petersburg. Along with his brother Victor, he got himself involved in Polish students' conspiracies and secret cultural societies, headed by Zygmunt Sierakowski and Jarosław Dąbrowski. After graduating in 1860, Konstanty traveled to Vilnius where he unsuccessfully applied to join the civil service under Vladimir Ivanovich Nazimov [ru].[3]
# Career
# Literary work
#
# Konstanty then returned to the Grodno area in 1861. Konstanty started publishing Mużyckaja prauda (Peasants' Truth), the first newspaper in Belarusian, written in Łacinka, first published in June 1862.[4] The Peasants' Truth was issued seven times until 1863.[3] Konstanty also published two other Polish language newspapers.[5] Konstanty was more aligned with the Reds which represented a democratic movement uniting peasants, workers, and some clergy rather than the more moderate Whites.[3]
#
# In his literary work, Kalinowski underlined the need to liberate all people of the former Polish–Lithuanian Commonwealth from Russia's occupation and to conserve and promote the Greek Catholic faith and Belarusian language. He also promoted the idea of activisation of peasants for the cause of national liberation, the idea that was until then dominated by the gentry. He favored the Polish–Lithuanian Commonwealth's traditions of democracy, tolerance and freedom, as opposed to national oppression of cultures dominated by Imperial Russia:
#
#     While the Polish Council gives all fraternal peoples self-help, the Muscovite not only does not do so, but even where Poles, Lithuanians and Belarusians lived, he opens Muscovite schools, and in these schools they teach in Muscovite language, where you will never hear a word in Polish, in Lithuanian or in Belarusian, as the people want [...][6][7]
#
# There is some academic debate about which texts to attribute to Konstanty.[2] Konstanty was unhappy with the timing and objectives of the January Uprising, which broke out on 23 January 1863. There had been a growing rift between him and other leaders of the uprising in Warsaw.[3]
#
# After the outbreak of the January Uprising, he was involved in the secret Provincial Lithuanian Committee [pl; be-tarask] in Vilnius. Soon he was promoted to the commissar of the Polish National Government for the Grodno Governorate. His writings made him popular both among the peasants and the gentry, which enabled the partisan units under his command to grow rapidly. Because of his successes he was promoted to the rank of Plenipotentiary Commissar of the Government for Lithuania (Polish: Komisarz Pełnomocny Rządu na Litwę), which made him the commander-in-chief of all partisan units fighting in the areas of the former Grand Duchy of Lithuania, which are in modern Lithuania, Belarus, eastern Poland and Ukraine.

# %%
#txt=trimmed_txt.lower()
tokens=nltk.word_tokenize(txt)
print(tokens)
punct_tokens=nltk.wordpunct_tokenize(txt)
print(punct_tokens)

vocabs=set(tokens)
print(vocabs)
# Out:
# ['Kalinowski', 'was', 'born', 'in', 'Mostowlany', ',', 'in', 'Grodnensky', 'Uyezd', 'of', 'the', 'Russian', 'Empire', '(', 'now', 'Mostowlany', ',', 'Poland', ')', 'to', 'a', 'szlachta', 'family', '.', 'The', 'Kalinowski', 'family', 'hailed', 'from', 'the', 'Polish', 'region', 'of', 'Mazovia', 'and', 'bore', 'the', 'Kalinowa', 'coat', 'of', 'arms', '.', 'His', 'father', ',', 'Szymon', ',', 'was', 'a', 'manager', 'of', 'the', 'Mostowlany', 'farm', 'and', 'manor', '.', 'His', 'older', 'brother', ',', 'Wiktor', 'Kalinowski', '[', 'be', ']', 'would', 'become', 'a', 'historian', '.', 'In', '1849', 'his', 'father', ',', 'Szymon', 'bought', 'a', 'folwark', 'near', 'Svislach', '(', 'now', 'Belarus', ')', 'where', 'Konstanty', 'grew', 'up', '.', '[', '3', ']', 'After', 'graduating', 'from', 'a', 'local', 'school', 'in', 'Svislach', 'in', '1855', ',', 'Kalinowski', 'entered', 'the', 'faculty', 'of', 'Medicine', 'of', 'the', 'University', 'of', 'Moscow', 'as', 'an', 'external', 'student', '.', '[', '3', ']', 'After', 'one', 'semester', 'he', 'moved', 'to', 'St.', 'Petersburg', ',', 'where', 'his', 'brother', 'was', 'and', 'joined', 'the', 'faculty', 'of', 'Law', 'at', 'the', 'University', 'of', 'St.', 'Petersburg', '.', 'Along', 'with', 'his', 'brother', 'Victor', ',', 'he', 'got', 'himself', 'involved', 'in', 'Polish', 'students', "'", 'conspiracies', 'and', 'secret', 'cultural', 'societies', ',', 'headed', 'by', 'Zygmunt', 'Sierakowski', 'and', 'Jarosław', 'Dąbrowski', '.', 'After', 'graduating', 'in', '1860', ',', 'Konstanty', 'traveled', 'to', 'Vilnius', 'where', 'he', 'unsuccessfully', 'applied', 'to', 'join', 'the', 'civil', 'service', 'under', 'Vladimir', 'Ivanovich', 'Nazimov', '[', 'ru', ']', '.', '[', '3', ']', 'Career', 'Literary', 'work', 'Konstanty', 'then', 'returned', 'to', 'the', 'Grodno', 'area', 'in', '1861', '.', 'Konstanty', 'started', 'publishing', 'Mużyckaja', 'prauda', '(', 'Peasants', "'", 'Truth', ')', ',', 'the', 'first', 'newspaper', 'in', 'Belarusian', ',', 'written', 'in', 'Łacinka', ',', 'first', 'published', 'in', 'June', '1862', '.', '[', '4', ']', 'The', 'Peasants', "'", 'Truth', 'was', 'issued', 'seven', 'times', 'until', '1863', '.', '[', '3', ']', 'Konstanty', 'also', 'published', 'two', 'other', 'Polish', 'language', 'newspapers', '.', '[', '5', ']', 'Konstanty', 'was', 'more', 'aligned', 'with', 'the', 'Reds', 'which', 'represented', 'a', 'democratic', 'movement', 'uniting', 'peasants', ',', 'workers', ',', 'and', 'some', 'clergy', 'rather', 'than', 'the', 'more', 'moderate', 'Whites', '.', '[', '3', ']', 'In', 'his', 'literary', 'work', ',', 'Kalinowski', 'underlined', 'the', 'need', 'to', 'liberate', 'all', 'people', 'of', 'the', 'former', 'Polish–Lithuanian', 'Commonwealth', 'from', 'Russia', "'s", 'occupation', 'and', 'to', 'conserve', 'and', 'promote', 'the', 'Greek', 'Catholic', 'faith', 'and', 'Belarusian', 'language', '.', 'He', 'also', 'promoted', 'the', 'idea', 'of', 'activisation', 'of', 'peasants', 'for', 'the', 'cause', 'of', 'national', 'liberation', ',', 'the', 'idea', 'that', 'was', 'until', 'then', 'dominated', 'by', 'the', 'gentry', '.', 'He', 'favored', 'the', 'Polish–Lithuanian', 'Commonwealth', "'s", 'traditions', 'of', 'democracy', ',', 'tolerance', 'and', 'freedom', ',', 'as', 'opposed', 'to', 'national', 'oppression', 'of', 'cultures', 'dominated', 'by', 'Imperial', 'Russia', ':', 'While', 'the', 'Polish', 'Council', 'gives', 'all', 'fraternal', 'peoples', 'self-help', ',', 'the', 'Muscovite', 'not', 'only', 'does', 'not', 'do', 'so', ',', 'but', 'even', 'where', 'Poles', ',', 'Lithuanians', 'and', 'Belarusians', 'lived', ',', 'he', 'opens', 'Muscovite', 'schools', ',', 'and', 'in', 'these', 'schools', 'they', 'teach', 'in', 'Muscovite', 'language', ',', 'where', 'you', 'will', 'never', 'hear', 'a', 'word', 'in', 'Polish', ',', 'in', 'Lithuanian', 'or', 'in', 'Belarusian', ',', 'as', 'the', 'people', 'want', '[', '...', ']', '[', '6', ']', '[', '7', ']', 'There', 'is', 'some', ...
# ['Kalinowski', 'was', 'born', 'in', 'Mostowlany', ',', 'in', 'Grodnensky', 'Uyezd', 'of', 'the', 'Russian', 'Empire', '(', 'now', 'Mostowlany', ',', 'Poland', ')', 'to', 'a', 'szlachta', 'family', '.', 'The', 'Kalinowski', 'family', 'hailed', 'from', 'the', 'Polish', 'region', 'of', 'Mazovia', 'and', 'bore', 'the', 'Kalinowa', 'coat', 'of', 'arms', '.', 'His', 'father', ',', 'Szymon', ',', 'was', 'a', 'manager', 'of', 'the', 'Mostowlany', 'farm', 'and', 'manor', '.', 'His', 'older', 'brother', ',', 'Wiktor', 'Kalinowski', '[', 'be', ']', 'would', 'become', 'a', 'historian', '.', 'In', '1849', 'his', 'father', ',', 'Szymon', 'bought', 'a', 'folwark', 'near', 'Svislach', '(', 'now', 'Belarus', ')', 'where', 'Konstanty', 'grew', 'up', '.[', '3', ']', 'After', 'graduating', 'from', 'a', 'local', 'school', 'in', 'Svislach', 'in', '1855', ',', 'Kalinowski', 'entered', 'the', 'faculty', 'of', 'Medicine', 'of', 'the', 'University', 'of', 'Moscow', 'as', 'an', 'external', 'student', '.[', '3', ']', 'After', 'one', 'semester', 'he', 'moved', 'to', 'St', '.', 'Petersburg', ',', 'where', 'his', 'brother', 'was', 'and', 'joined', 'the', 'faculty', 'of', 'Law', 'at', 'the', 'University', 'of', 'St', '.', 'Petersburg', '.', 'Along', 'with', 'his', 'brother', 'Victor', ',', 'he', 'got', 'himself', 'involved', 'in', 'Polish', 'students', "'", 'conspiracies', 'and', 'secret', 'cultural', 'societies', ',', 'headed', 'by', 'Zygmunt', 'Sierakowski', 'and', 'Jarosław', 'Dąbrowski', '.', 'After', 'graduating', 'in', '1860', ',', 'Konstanty', 'traveled', 'to', 'Vilnius', 'where', 'he', 'unsuccessfully', 'applied', 'to', 'join', 'the', 'civil', 'service', 'under', 'Vladimir', 'Ivanovich', 'Nazimov', '[', 'ru', '].[', '3', ']', 'Career', 'Literary', 'work', 'Konstanty', 'then', 'returned', 'to', 'the', 'Grodno', 'area', 'in', '1861', '.', 'Konstanty', 'started', 'publishing', 'Mużyckaja', 'prauda', '(', 'Peasants', "'", 'Truth', '),', 'the', 'first', 'newspaper', 'in', 'Belarusian', ',', 'written', 'in', 'Łacinka', ',', 'first', 'published', 'in', 'June', '1862', '.[', '4', ']', 'The', 'Peasants', "'", 'Truth', 'was', 'issued', 'seven', 'times', 'until', '1863', '.[', '3', ']', 'Konstanty', 'also', 'published', 'two', 'other', 'Polish', 'language', 'newspapers', '.[', '5', ']', 'Konstanty', 'was', 'more', 'aligned', 'with', 'the', 'Reds', 'which', 'represented', 'a', 'democratic', 'movement', 'uniting', 'peasants', ',', 'workers', ',', 'and', 'some', 'clergy', 'rather', 'than', 'the', 'more', 'moderate', 'Whites', '.[', '3', ']', 'In', 'his', 'literary', 'work', ',', 'Kalinowski', 'underlined', 'the', 'need', 'to', 'liberate', 'all', 'people', 'of', 'the', 'former', 'Polish', '–', 'Lithuanian', 'Commonwealth', 'from', 'Russia', "'", 's', 'occupation', 'and', 'to', 'conserve', 'and', 'promote', 'the', 'Greek', 'Catholic', 'faith', 'and', 'Belarusian', 'language', '.', 'He', 'also', 'promoted', 'the', 'idea', 'of', 'activisation', 'of', 'peasants', 'for', 'the', 'cause', 'of', 'national', 'liberation', ',', 'the', 'idea', 'that', 'was', 'until', 'then', 'dominated', 'by', 'the', 'gentry', '.', 'He', 'favored', 'the', 'Polish', '–', 'Lithuanian', 'Commonwealth', "'", 's', 'traditions', 'of', 'democracy', ',', 'tolerance', 'and', 'freedom', ',', 'as', 'opposed', 'to', 'national', 'oppression', 'of', 'cultures', 'dominated', 'by', 'Imperial', 'Russia', ':', 'While', 'the', 'Polish', 'Council', 'gives', 'all', 'fraternal', 'peoples', 'self', '-', 'help', ',', 'the', 'Muscovite', 'not', 'only', 'does', 'not', 'do', 'so', ',', 'but', 'even', 'where', 'Poles', ',', 'Lithuanians', 'and', 'Belarusians', 'lived', ',', 'he', 'opens', 'Muscovite', 'schools', ',', 'and', 'in', 'these', 'schools', 'they', 'teach', 'in', 'Muscovite', 'language', ',', 'where', 'you', 'will', 'never', 'hear', 'a', 'word', 'in', 'Polish', ',', 'in', 'Lithuanian', 'or', 'in', 'Belarusian', ',', 'as', 'the', 'people', 'want', '[...][', '6', '][', '7', ']', 'There', 'is', 'some', 'academic', ...
# {'not', ';', 'Kalinowski', 'Svislach', 'is', 'the', 'would', 'unsuccessfully', 'Lithuania', '[', 'also', 'Mazovia', 'popular', 'While', 'Plenipotentiary', 'dominated', 'on', 'commissar', 'modern', 'After', 'conserve', 'promoted', 'Peasants', 'are', 'Victor', 'be', 'older', 'want', 'self-help', 'schools', 'grow', 'now', 'published', 'Vladimir', 'then', 'Truth', 'he', '.', 'cultural', 'entered', 'region', 'students', 'word', 'rapidly', 'Wiktor', 'Reds', 'former', 'even', 'need', 'got', 'external', 'Dąbrowski', 'or', 'grew', 'himself', 'clergy', 'these', 'partisan', 'Medicine', 'command', '1855', 'opens', 'an', 'enabled', '1862', 'but', 'Rządu', 'that', 'seven', 'between', 'will', 'Łacinka', 'pl', 'school', 'Zygmunt', 'civil', 'with', 'Ukraine', 'movement', 'two', 'democratic', 'liberate', 'semester', 'Governorate', 'Vilnius', 'him', 'rank', 'objectives', 'attribute', 'graduating', 'leaders', 'join', 'manor', 'secret', '(', 'The', 'manager', 'Council', 'historian', 'traditions', 'Along', 'born', '1860', ':', 'Szymon', 'units', 'publishing', 'brother', ']', 'Grand', 'rather', 'aligned', 'tolerance', 'cause', 'freedom', ')', 'written', 'represented', 'faith', 'academic', 'to', 'a', 'up', 'under', 'He', 'one', 'Mostowlany', 'so', '23', 'Russian', 'all', 'other', 'texts', 'service', 'involved', 'Literary', 'favored', 'uniting', 'There', 'Nazimov', 'lived', 'returned', 'activisation', 'joined', 'gentry', 'headed', 'University', 'szlachta', 'national', 'fraternal', 'Because', 'Commissar', 'eastern', 'debate', 'areas', 'Whites', 'Ivanovich', 'Provincial', 'student', 'peoples', 'work', 'occupation', 'at', 'Poles', 'from', 'Kalinowa', 'they', 'Uprising', 'local', 'of', 'na', 'Greek', 'issued', 'fighting', 'folwark', 'near', '2', "'", 'been', 'Empire', 'rift', 'Jarosław', 'area', 'hear', 'Litwę', 'Imperial', '...', 'faculty', 'and', 'teach', 'about', 'Muscovite', 'moderate', 'Russia', 'growing', 'some', 'among', 'Uyezd', 'Law', 'Commonwealth', 'Komisarz', 'farm', 'commander-in-chief', 'out', 'literary', '5', 'bore', 'underlined', 'made', 'Polish', 'applied', '3', '1863', 'by', 'Soon', ',', 'January', 'which', 'as', 'Catholic', 'Petersburg', 'His', '1861', 'liberation', 'does', 'be-tarask', 'outbreak', 'Pełnomocny', 'ru', '1849', '4', 'where', 'people', 'only', 'for', 'writings', 'bought', 'Konstanty', 'Career', 'language', 'moved', 'uprising', 'Mużyckaja', 'prauda', 'opposed', '7', 'Lithuanian', 'coat', 'St.', 'Sierakowski', 'idea', 'National', 'June', 'Moscow', 'Polish–Lithuanian', "'s", 'both', 'successes', 'unhappy', 'gives', 'family', 'arms', 'cultures', 'in', 'timing', 'than', 'more', 'hailed', 'oppression', 'do', 'first', 'Poland', 'In', 'peasants', 'times', 'started', 'was', 'societies', 'democracy', 'Belarusians', 'Government', 'never', 'broke', 'Belarusian', 'conspiracies', 'Warsaw', 'Lithuanians', 'become', 'traveled', 'newspaper', 'workers', 'until', 'had', 'Committee', 'Belarus', 'promote', 'Duchy', 'you', 'newspapers', 'Grodnensky', 'Grodno', 'his', 'father', '6'}

# %%
wo_stopwords=vocabs-set(stopwords.words("english"))
print(wo_stopwords)
import string
wo_punct=wo_stopwords-set(string.punctuation)
print(wo_punct)

from nltk.stem.snowball import SnowballStemmer
stemmed_list= []
stemObj = SnowballStemmer("english")
for i in wo_punct:
    stemmed_list.append(stemObj.stem(i))
print(stemmed_list)
nltk.download('wordnet')
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer

pos_tag_list = nltk.pos_tag(wo_punct)
# print(pos_tag_list)
#for getting parts of speech
def parts_of_speech(pos):
    if pos.startswith("N"):
        return wordnet.NOUN
    elif pos.startswith("J"):
        return wordnet.ADJ
    elif pos.startswith("V"):
        return wordnet.VERB
    elif pos.startswith("R"):
        return wordnet.ADV
    elif pos.startswith("S"):
        return wordnet.ADJ_SAT
    else:
        return ''
#lemmatization
lemma_list = []
lemmaObj =  WordNetLemmatizer()
for word,pos in pos_tag_list:
    get_pos = parts_of_speech(pos)
    if get_pos != '':
        lemma_list.append(lemmaObj.lemmatize(word, pos = get_pos))
    else:
        lemma_list.append(word)
print(lemma_list)
# Out:
# {';', 'Kalinowski', 'Svislach', 'would', 'unsuccessfully', 'Lithuania', '[', 'also', 'Mazovia', 'popular', 'While', 'Plenipotentiary', 'dominated', 'modern', 'After', 'conserve', 'promoted', 'Peasants', 'Victor', 'older', 'want', 'self-help', 'schools', 'grow', 'published', 'Vladimir', 'Truth', '.', 'cultural', 'entered', 'region', 'students', 'word', 'rapidly', 'Wiktor', 'Reds', 'former', 'even', 'need', 'got', 'external', 'Dąbrowski', 'grew', 'clergy', 'command', 'partisan', 'Medicine', '1855', 'opens', 'enabled', '1862', 'Rządu', 'seven', 'Łacinka', 'pl', 'civil', 'Ukraine', 'school', 'Zygmunt', 'movement', 'two', 'democratic', 'liberate', 'semester', 'Governorate', 'Vilnius', 'rank', 'objectives', 'attribute', 'graduating', 'join', 'manor', 'secret', '(', 'The', 'manager', 'Council', 'historian', 'traditions', 'Along', 'born', '1860', ':', 'Szymon', 'units', 'publishing', 'brother', ']', 'Grand', 'rather', 'aligned', 'leaders', 'tolerance', 'cause', 'freedom', ')', 'written', 'represented', 'faith', 'academic', 'He', 'one', 'Mostowlany', '23', 'Russian', 'texts', 'service', 'involved', 'Literary', 'favored', 'uniting', 'There', 'Nazimov', 'lived', 'returned', 'activisation', 'joined', 'gentry', 'headed', 'University', 'szlachta', 'national', 'fraternal', 'Because', 'Commissar', 'eastern', 'debate', 'areas', 'Whites', 'Ivanovich', 'Provincial', 'student', 'peoples', 'work', 'occupation', 'Poles', 'Kalinowa', 'Uprising', 'local', 'na', 'Greek', 'issued', 'fighting', 'folwark', 'near', '2', "'", 'Empire', 'rift', 'Jarosław', 'area', 'hear', 'Litwę', 'Imperial', '...', 'faculty', 'teach', 'Muscovite', 'moderate', 'Russia', 'growing', 'among', 'Uyezd', 'Law', 'Commonwealth', 'Komisarz', 'farm', 'commander-in-chief', 'literary', '5', 'bore', 'underlined', 'made', 'Polish', 'applied', '3', '1863', 'Soon', ',', 'January', 'be-tarask', 'Catholic', 'liberation', 'Petersburg', 'His', '1861', 'Pełnomocny', 'outbreak', 'ru', '1849', '4', 'people', 'writings', 'bought', 'Konstanty', 'Career', 'language', 'moved', 'uprising', 'Mużyckaja', '6', 'prauda', 'opposed', '7', 'Lithuanian', 'coat', 'St.', 'Sierakowski', 'idea', 'National', 'June', 'Moscow', 'Polish–Lithuanian', "'s", 'successes', 'unhappy', 'gives', 'family', 'arms', 'cultures', 'timing', 'oppression', 'hailed', 'first', 'Poland', 'In', 'peasants', 'times', 'started', 'societies', 'democracy', 'Belarusians', 'Government', 'never', 'broke', 'Belarusian', 'conspiracies', 'Warsaw', 'Lithuanians', 'become', 'traveled', 'newspaper', 'workers', 'Duchy', 'Committee', 'Belarus', 'promote', 'newspapers', 'Grodnensky', 'Grodno', 'father', 'commissar'}
# {'Kalinowski', 'Svislach', 'would', 'unsuccessfully', 'Lithuania', 'also', 'Mazovia', 'popular', 'While', 'Plenipotentiary', 'dominated', 'modern', 'After', 'conserve', 'promoted', 'Peasants', 'Victor', 'older', 'want', 'self-help', 'schools', 'grow', 'published', 'Vladimir', 'Truth', 'cultural', 'entered', 'region', 'students', 'word', 'rapidly', 'Wiktor', 'Reds', 'former', 'even', 'need', 'got', 'external', 'Dąbrowski', 'grew', 'clergy', 'command', 'partisan', 'Medicine', '1855', 'opens', 'enabled', '1862', 'Rządu', 'seven', 'Łacinka', 'pl', 'civil', 'Ukraine', 'school', 'Zygmunt', 'movement', 'two', 'democratic', 'liberate', 'semester', 'Governorate', 'Vilnius', 'rank', 'objectives', 'attribute', 'graduating', 'join', 'manor', 'secret', 'The', 'manager', 'Council', 'historian', 'traditions', 'Along', 'born', '1860', 'Szymon', 'units', 'publishing', 'brother', 'Grand', 'rather', 'aligned', 'leaders', 'tolerance', 'cause', 'freedom', 'written', 'represented', 'faith', 'academic', 'He', 'one', 'Mostowlany', '23', 'Russian', 'texts', 'service', 'involved', 'Literary', 'favored', 'uniting', 'There', 'Nazimov', 'lived', 'returned', 'activisation', 'joined', 'gentry', 'headed', 'University', 'szlachta', 'national', 'fraternal', 'Because', 'Commissar', 'eastern', 'debate', 'areas', 'Whites', 'Ivanovich', 'Provincial', 'student', 'peoples', 'work', 'occupation', 'Poles', 'Kalinowa', 'Uprising', 'local', 'na', 'Greek', 'issued', 'fighting', 'folwark', 'near', '2', 'Empire', 'rift', 'Jarosław', 'area', 'hear', 'Litwę', 'Imperial', '...', 'faculty', 'teach', 'Muscovite', 'moderate', 'Russia', 'growing', 'among', 'Uyezd', 'Law', 'Commonwealth', 'Komisarz', 'farm', 'commander-in-chief', 'literary', '5', 'bore', 'underlined', 'made', 'Polish', 'applied', '3', '1863', 'Soon', 'January', 'be-tarask', 'Catholic', 'liberation', 'Petersburg', 'His', '1861', 'Pełnomocny', 'outbreak', 'ru', '1849', '4', 'people', 'writings', 'bought', 'Konstanty', 'Career', 'language', 'moved', 'uprising', 'Mużyckaja', '6', 'prauda', 'opposed', '7', 'Lithuanian', 'coat', 'St.', 'Sierakowski', 'idea', 'National', 'June', 'Moscow', 'Polish–Lithuanian', "'s", 'successes', 'unhappy', 'gives', 'family', 'arms', 'cultures', 'timing', 'oppression', 'hailed', 'first', 'Poland', 'In', 'peasants', 'times', 'started', 'societies', 'democracy', 'Belarusians', 'Government', 'never', 'broke', 'Belarusian', 'conspiracies', 'Warsaw', 'Lithuanians', 'become', 'traveled', 'newspaper', 'workers', 'Duchy', 'Committee', 'Belarus', 'promote', 'newspapers', 'Grodnensky', 'Grodno', 'father', 'commissar'}
# ['kalinowski', 'svislach', 'would', 'unsuccess', 'lithuania', 'also', 'mazovia', 'popular', 'while', 'plenipotentiari', 'domin', 'modern', 'after', 'conserv', 'promot', 'peasant', 'victor', 'older', 'want', 'self-help', 'school', 'grow', 'publish', 'vladimir', 'truth', 'cultur', 'enter', 'region', 'student', 'word', 'rapid', 'wiktor', 'red', 'former', 'even', 'need', 'got', 'extern', 'dąbrowski', 'grew', 'clergi', 'command', 'partisan', 'medicin', '1855', 'open', 'enabl', '1862', 'rządu', 'seven', 'łacinka', 'pl', 'civil', 'ukrain', 'school', 'zygmunt', 'movement', 'two', 'democrat', 'liber', 'semest', 'governor', 'vilnius', 'rank', 'object', 'attribut', 'graduat', 'join', 'manor', 'secret', 'the', 'manag', 'council', 'historian', 'tradit', 'along', 'born', '1860', 'szymon', 'unit', 'publish', 'brother', 'grand', 'rather', 'align', 'leader', 'toler', 'caus', 'freedom', 'written', 'repres', 'faith', 'academ', 'he', 'one', 'mostowlani', '23', 'russian', 'text', 'servic', 'involv', 'literari', 'favor', 'unit', 'there', 'nazimov', 'live', 'return', 'activis', 'join', 'gentri', 'head', 'univers', 'szlachta', 'nation', 'fratern', 'becaus', 'commissar', 'eastern', 'debat', 'area', 'white', 'ivanovich', 'provinci', 'student', 'peopl', 'work', 'occup', 'pole', 'kalinowa', 'upris', 'local', 'na', 'greek', 'issu', 'fight', 'folwark', 'near', '2', 'empir', 'rift', 'jarosław', 'area', 'hear', 'litwę', 'imperi', '...', 'faculti', 'teach', 'muscovit', 'moder', 'russia', 'grow', 'among', 'uyezd', 'law', 'commonwealth', 'komisarz', 'farm', 'commander-in-chief', 'literari', '5', 'bore', 'underlin', 'made', 'polish', 'appli', '3', '1863', 'soon', 'januari', 'be-tarask', 'cathol', 'liber', 'petersburg', 'his', '1861', 'pełnomocni', 'outbreak', 'ru', '1849', '4', 'peopl', 'write', 'bought', 'konstanti', 'career', 'languag', 'move', 'upris', 'mużyckaja', '6', 'prauda', 'oppos', '7', 'lithuanian', 'coat', 'st.', 'sierakowski', 'idea', 'nation', 'june', 'moscow', 'polish–lithuanian', "'s", 'success', 'unhappi', 'give', 'famili', 'arm', 'cultur', 'time', 'oppress', 'hail', 'first', 'poland', 'in', 'peasant', 'time', 'start', 'societi', 'democraci', 'belarusian', 'govern', 'never', 'broke', 'belarusian', 'conspiraci', 'warsaw', 'lithuanian', 'becom', 'travel', 'newspap', 'worker', 'duchi', 'committe', 'belarus', 'promot', 'newspap', 'grodnenski', 'grodno', 'father', 'commissar']
# ['Kalinowski', 'Svislach', 'would', 'unsuccessfully', 'Lithuania', 'also', 'Mazovia', 'popular', 'While', 'Plenipotentiary', 'dominate', 'modern', 'After', 'conserve', 'promote', 'Peasants', 'Victor', 'old', 'want', 'self-help', 'school', 'grow', 'publish', 'Vladimir', 'Truth', 'cultural', 'enter', 'region', 'student', 'word', 'rapidly', 'Wiktor', 'Reds', 'former', 'even', 'need', 'get', 'external', 'Dąbrowski', 'grow', 'clergy', 'command', 'partisan', 'Medicine', '1855', 'open', 'enabled', '1862', 'Rządu', 'seven', 'Łacinka', 'pl', 'civil', 'Ukraine', 'school', 'Zygmunt', 'movement', 'two', 'democratic', 'liberate', 'semester', 'Governorate', 'Vilnius', 'rank', 'objective', 'attribute', 'graduate', 'join', 'manor', 'secret', 'The', 'manager', 'Council', 'historian', 'tradition', 'Along', 'born', '1860', 'Szymon', 'unit', 'publish', 'brother', 'Grand', 'rather', 'align', 'leader', 'tolerance', 'cause', 'freedom', 'write', 'represent', 'faith', 'academic', 'He', 'one', 'Mostowlany', '23', 'Russian', 'text', 'service', 'involve', 'Literary', 'favor', 'unite', 'There', 'Nazimov', 'live', 'return', 'activisation', 'join', 'gentry', 'head', 'University', 'szlachta', 'national', 'fraternal', 'Because', 'Commissar', 'eastern', 'debate', 'area', 'Whites', 'Ivanovich', 'Provincial', 'student', 'people', 'work', 'occupation', 'Poles', 'Kalinowa', 'Uprising', 'local', 'na', 'Greek', 'issue', 'fight', 'folwark', 'near', '2', 'Empire', 'rift', 'Jarosław', 'area', 'hear', 'Litwę', 'Imperial', '...', 'faculty', 'teach', 'Muscovite', 'moderate', 'Russia', 'grow', 'among', 'Uyezd', 'Law', 'Commonwealth', 'Komisarz', 'farm', 'commander-in-chief', 'literary', '5', 'bore', 'underlined', 'make', 'Polish', 'apply', '3', '1863', 'Soon', 'January', 'be-tarask', 'Catholic', 'liberation', 'Petersburg', 'His', '1861', 'Pełnomocny', 'outbreak', 'ru', '1849', '4', 'people', 'writing', 'buy', 'Konstanty', 'Career', 'language', 'move', 'uprising', 'Mużyckaja', '6', 'prauda', 'oppose', '7', 'Lithuanian', 'coat', 'St.', 'Sierakowski', 'idea', 'National', 'June', 'Moscow', 'Polish–Lithuanian', "'s", 'success', 'unhappy', 'give', 'family', 'arm', 'culture', 'time', 'oppression', 'hail', 'first', 'Poland', 'In', 'peasant', 'time', 'start', 'society', 'democracy', 'Belarusians', 'Government', 'never', 'break', 'Belarusian', 'conspiracy', 'Warsaw', 'Lithuanians', 'become', 'traveled', 'newspaper', 'worker', 'Duchy', 'Committee', 'Belarus', 'promote', 'newspaper', 'Grodnensky', 'Grodno', 'father', 'commissar']
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
bigrams=nltk.ngrams(wo_punct,2)
print(list(bigrams))
# Out:
# [('Kalinowski', 'Svislach'), ('Svislach', 'would'), ('would', 'unsuccessfully'), ('unsuccessfully', 'Lithuania'), ('Lithuania', 'also'), ('also', 'Mazovia'), ('Mazovia', 'popular'), ('popular', 'While'), ('While', 'Plenipotentiary'), ('Plenipotentiary', 'dominated'), ('dominated', 'modern'), ('modern', 'After'), ('After', 'conserve'), ('conserve', 'promoted'), ('promoted', 'Peasants'), ('Peasants', 'Victor'), ('Victor', 'older'), ('older', 'want'), ('want', 'self-help'), ('self-help', 'schools'), ('schools', 'grow'), ('grow', 'published'), ('published', 'Vladimir'), ('Vladimir', 'Truth'), ('Truth', 'cultural'), ('cultural', 'entered'), ('entered', 'region'), ('region', 'students'), ('students', 'word'), ('word', 'rapidly'), ('rapidly', 'Wiktor'), ('Wiktor', 'Reds'), ('Reds', 'former'), ('former', 'even'), ('even', 'need'), ('need', 'got'), ('got', 'external'), ('external', 'Dąbrowski'), ('Dąbrowski', 'grew'), ('grew', 'clergy'), ('clergy', 'command'), ('command', 'partisan'), ('partisan', 'Medicine'), ('Medicine', '1855'), ('1855', 'opens'), ('opens', 'enabled'), ('enabled', '1862'), ('1862', 'Rządu'), ('Rządu', 'seven'), ('seven', 'Łacinka'), ('Łacinka', 'pl'), ('pl', 'civil'), ('civil', 'Ukraine'), ('Ukraine', 'school'), ('school', 'Zygmunt'), ('Zygmunt', 'movement'), ('movement', 'two'), ('two', 'democratic'), ('democratic', 'liberate'), ('liberate', 'semester'), ('semester', 'Governorate'), ('Governorate', 'Vilnius'), ('Vilnius', 'rank'), ('rank', 'objectives'), ('objectives', 'attribute'), ('attribute', 'graduating'), ('graduating', 'join'), ('join', 'manor'), ('manor', 'secret'), ('secret', 'The'), ('The', 'manager'), ('manager', 'Council'), ('Council', 'historian'), ('historian', 'traditions'), ('traditions', 'Along'), ('Along', 'born'), ('born', '1860'), ('1860', 'Szymon'), ('Szymon', 'units'), ('units', 'publishing'), ('publishing', 'brother'), ('brother', 'Grand'), ('Grand', 'rather'), ('rather', 'aligned'), ('aligned', 'leaders'), ('leaders', 'tolerance'), ('tolerance', 'cause'), ('cause', 'freedom'), ('freedom', 'written'), ('written', 'represented'), ('represented', 'faith'), ('faith', 'academic'), ('academic', 'He'), ('He', 'one'), ('one', 'Mostowlany'), ('Mostowlany', '23'), ('23', 'Russian'), ('Russian', 'texts'), ('texts', 'service'), ('service', 'involved'), ('involved', 'Literary'), ('Literary', 'favored'), ('favored', 'uniting'), ('uniting', 'There'), ('There', 'Nazimov'), ('Nazimov', 'lived'), ('lived', 'returned'), ('returned', 'activisation'), ('activisation', 'joined'), ('joined', 'gentry'), ('gentry', 'headed'), ('headed', 'University'), ('University', 'szlachta'), ('szlachta', 'national'), ('national', 'fraternal'), ('fraternal', 'Because'), ('Because', 'Commissar'), ('Commissar', 'eastern'), ('eastern', 'debate'), ('debate', 'areas'), ('areas', 'Whites'), ('Whites', 'Ivanovich'), ('Ivanovich', 'Provincial'), ('Provincial', 'student'), ('student', 'peoples'), ('peoples', 'work'), ('work', 'occupation'), ('occupation', 'Poles'), ('Poles', 'Kalinowa'), ('Kalinowa', 'Uprising'), ('Uprising', 'local'), ('local', 'na'), ('na', 'Greek'), ('Greek', 'issued'), ('issued', 'fighting'), ('fighting', 'folwark'), ('folwark', 'near'), ('near', '2'), ('2', 'Empire'), ('Empire', 'rift'), ('rift', 'Jarosław'), ('Jarosław', 'area'), ('area', 'hear'), ('hear', 'Litwę'), ('Litwę', 'Imperial'), ('Imperial', '...'), ('...', 'faculty'), ('faculty', 'teach'), ('teach', 'Muscovite'), ('Muscovite', 'moderate'), ('moderate', 'Russia'), ('Russia', 'growing'), ('growing', 'among'), ('among', 'Uyezd'), ('Uyezd', 'Law'), ('Law', 'Commonwealth'), ('Commonwealth', 'Komisarz'), ('Komisarz', 'farm'), ('farm', 'commander-in-chief'), ('commander-in-chief', 'literary'), ('literary', '5'), ('5', 'bore'), ('bore', 'underlined'), ('underlined', 'made'), ('made', 'Polish'), ('Polish', 'applied'), ('applied', '3'), ('3', '1863'), ('1863', 'Soon'), ('Soon', 'January'), ('January', 'be-tarask'), ('be-tarask', 'Catholic'), ('Catholic', 'liberatio ...

# %%
nltk.download('words')
def find(texts):
 unusuals=set(w.lower() for w in texts if w.isalpha()) - set(w.lower() for w in nltk.corpus.words.words())
 return unusuals

print(find(punct_tokens))
unusual_words_found =['helo','hai']#find(punct_tokens)
from nltk.metrics import edit_distance
possible_suggestions={}
english_vocab_set = set(w.lower() for w in nltk.corpus.words.words())
for unusual_word in unusual_words_found:
    for word in english_vocab_set:
        dist = edit_distance(unusual_word,word)
        if dist<len(unusual_word)/2:
            if unusual_word not in possible_suggestions.keys():
                possible_suggestions[unusual_word] = [word]
            else:
                possible_suggestions[unusual_word].append(word)
print(possible_suggestions)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# {'lithuania', 'svislach', 'konstanty', 'wiktor', 'vilnius', 'mazovia', 'szymon', 'writings', 'pełnomocny', 'moved', 'reds', 'prauda', 'poland', 'komisarz', 'objectives', 'tarask', 'łacinka', 'kalinowa', 'jarosław', 'issued', 'grodnensky', 'nazimov', 'traditions', 'kalinowski', 'dąbrowski', 'folwark', 'successes', 'units', 'gives', 'promoted', 'zygmunt', 'publishing', 'ru', 'cultures', 'petersburg', 'mużyckaja', 'aligned', 'schools', 'belarus', 'leaders', 'represented', 'poles', 'uyezd', 'hailed', 'peasants', 'published', 'started', 'entered', 'societies', 'students', 'ukraine', 'texts', 'belarusians', 'lithuanians', 'rządu', 'mostowlany', 'underlined', 'conspiracies', 'activisation', 'joined', 'opens', 'sierakowski', 'enabled', 'grodno', 'workers', 'areas', 'litwę', 'newspapers', 'belarusian', 'pl', 'ivanovich', 'peoples'}
# {'helo': ['helio', 'halo', 'ohelo', 'help', 'heloe', 'hero', 'hele', 'hello', 'helm', 'helot', 'hell', 'velo'], 'hai': ['hui', 'hat', 'shai', 'kai', 'hati', 'hau', 'sai', 'hak', 'lai', 'hei', 'hag', 'chai', 'tai', 'hair', 'hoi', 'ha', 'hi', 'hao', 'thai', 'hah', 'hain', 'hsi', 'dhai', 'vai', 'hal', 'had', 'ai', 'han', 'hail', 'hami', 'haw', 'hapi', 'ham', 'hap', 'haik', 'hagi', 'hay']}
