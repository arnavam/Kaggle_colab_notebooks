# %%
import tensorflow as tf
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
a=tf.Variable(24)
a=tf.Variable([[1,2],[2,3],[5,6]],tf.float64)
a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-bd47053e6c1a> in <cell line: 3>()
#       1 a=tf.Variable(24)
#       2 a=tf.Variable([[1,2],[2,3],[5,6]],tf.float64)
# ----> 3 a.ones
#
# AttributeError: 'ResourceVariable' object has no attribute 'ones'
